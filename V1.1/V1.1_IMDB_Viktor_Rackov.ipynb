# %% [markdown]
# # V1.1
#
# **Avtor:** Viktor Rackov

# %%
import os, numpy as np, matplotlib.pyplot as plt
os.environ.setdefault("TF_CPP_MIN_LOG_LEVEL", "2")

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers

NUM_WORDS = 3000
VAL_SPLIT = 10000
EPOCHS = 30
BATCH_SIZE = 512
RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
print(tf.__version__)
# Out:
# 2.20.0

# %% [markdown]
# ## Nalaganje IMDB in *multi-hot* vektorizacija

# %%
def vectorize_sequences(sequences, dimension=NUM_WORDS):
    result = np.zeros((len(sequences), dimension), dtype="float32")
    for i, seq in enumerate(sequences):
        idx = np.unique([w for w in seq if 0 <= w < dimension])
        result[i, idx] = 1.0
    return result

(x_train, y_train), (x_test, y_test) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)
x_train_vec = vectorize_sequences(x_train, NUM_WORDS)
x_test_vec  = vectorize_sequences(x_test, NUM_WORDS)
x_train_vec.shape, x_test_vec.shape
# Out:
# ((25000, 3000), (25000, 3000))

# %% [markdown]
# ## Razdelitev na učenje/validacijo in model

# %%
x_val, y_val = x_train_vec[:VAL_SPLIT], y_train[:VAL_SPLIT]
partial_x_train, partial_y_train = x_train_vec[VAL_SPLIT:], y_train[VAL_SPLIT:]

model = keras.Sequential([
    keras.Input(shape=(NUM_WORDS,)),
    layers.Dense(16, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │        48,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 48,305 (188.69 KB)
#  Trainable params: 48,305 (188.69 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Učenje

# %%
history = model.fit(
    partial_x_train, partial_y_train,
    epochs=EPOCHS, batch_size=BATCH_SIZE,
    validation_data=(x_val, y_val),
    verbose=2
)
# Out:
# Epoch 1/30
# 30/30 - 0s - 15ms/step - accuracy: 0.7300 - loss: 0.6037 - val_accuracy: 0.8254 - val_loss: 0.4895
# Epoch 2/30
# 30/30 - 0s - 2ms/step - accuracy: 0.8633 - loss: 0.3990 - val_accuracy: 0.8648 - val_loss: 0.3521
# Epoch 3/30
# 30/30 - 0s - 2ms/step - accuracy: 0.8934 - loss: 0.2922 - val_accuracy: 0.8771 - val_loss: 0.3073
# Epoch 4/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9101 - loss: 0.2442 - val_accuracy: 0.8796 - val_loss: 0.2977
# Epoch 5/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9201 - loss: 0.2163 - val_accuracy: 0.8795 - val_loss: 0.2996
# Epoch 6/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9271 - loss: 0.1968 - val_accuracy: 0.8800 - val_loss: 0.3073
# Epoch 7/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9327 - loss: 0.1816 - val_accuracy: 0.8785 - val_loss: 0.3183
# Epoch 8/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9371 - loss: 0.1693 - val_accuracy: 0.8745 - val_loss: 0.3316
# Epoch 9/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9414 - loss: 0.1605 - val_accuracy: 0.8715 - val_loss: 0.3503
# Epoch 10/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9440 - loss: 0.1532 - val_accuracy: 0.8690 - val_loss: 0.3667
# Epoch 11/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9475 - loss: 0.1449 - val_accuracy: 0.8677 - val_loss: 0.3771
# Epoch 12/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9508 - loss: 0.1354 - val_accuracy: 0.8672 - val_loss: 0.3897
# Epoch 13/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9562 - loss: 0.1248 - val_accuracy: 0.8611 - val_loss: 0.4120
# Epoch 14/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9558 - loss: 0.1180 - val_accuracy: 0.8612 - val_loss: 0.4227
# Epoch 15/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9499 - loss: 0.1219 - val_accuracy: 0.8564 - val_loss: 0.4648
# Epoch 16/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9467 - loss: 0.1284 - val_accuracy: 0.8612 - val_loss: 0.4261
# Epoch 17/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9673 - loss: 0.0935 - val_accuracy: 0.8550 - val_loss: 0.4660
# Epoch 18/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9704 - loss: 0.0889 - val_accuracy: 0.8545 - val_loss: 0.4723
# Epoch 19/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9695 - loss: 0.0879 - val_accuracy: 0.8444 - val_loss: 0.5300
# Epoch 20/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9668 - loss: 0.0904 - val_accuracy: 0.8400 - val_loss: 0.5613
# Epoch 21/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9498 - loss: 0.1163 - val_accuracy: 0.8577 - val_loss: 0.4937
# Epoch 22/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9329 - loss: 0.1528 - val_accuracy: 0.8522 - val_loss: 0.5029
# Epoch 23/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9467 - loss: 0.1256 - val_accuracy: 0.8441 - val_loss: 0.5632
# Epoch 24/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9681 - loss: 0.0850 - val_accuracy: 0.8625 - val_loss: 0.4702
# Epoch 25/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9892 - loss: 0.0459 - val_accuracy: 0.8626 - val_loss: 0.5068
# Epoch 26/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9917 - loss: 0.0403 - val_accuracy: 0.8624 - val_loss: 0.5156
# Epoch 27/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9941 - loss: 0.0350 - val_accuracy: 0.8621 - val_loss: 0.5287
# Epoch 28/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9959 - loss: 0.0313 - val_accuracy: 0.8610 - val_loss: 0.5407
# Epoch 29/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9971 - loss: 0.0282 - val_accuracy: 0.8590 - val_loss: 0.5531
# Epoch 30/30
# 30/30 - 0s - 2ms/step - accuracy: 0.9975 - loss: 0.0255 - val_accuracy: 0.8580 - val_loss: 0.5665

# %% [markdown]
# ## Grafi izgube in točnosti

# %%
hist = history.history

# Loss
plt.figure()
plt.plot(hist['loss'], label='train_loss')
plt.plot(hist['val_loss'], label='val_loss')
plt.xlabel('Epoch'); plt.ylabel('Loss (BCE)'); plt.title('Training vs Validation Loss')
plt.legend(); plt.grid(True, alpha=0.3)
plt.show()

# Accuracy
plt.figure()
plt.plot(hist['accuracy'], label='train_acc')
plt.plot(hist['val_accuracy'], label='val_acc')
plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.title('Training vs Validation Accuracy')
plt.legend(); plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## Detekcija prekomernega prileganja (overfitting)

# %%
import numpy as np
val_loss = np.array(hist['val_loss'], dtype=float)
loss = np.array(hist['loss'], dtype=float)

best_epoch = int(np.argmin(val_loss)) + 1  # 1-based
start_epoch = None
for i in range(1, len(val_loss)):
    if (val_loss[i] > val_loss[i-1]) and (loss[i] < loss[i-1]):
        start_epoch = i + 1  # 1-based
        break

print(f"Najboljši epoch po val_loss: {best_epoch}")
if start_epoch is not None:
    print(f"Prekomerno prileganje se začne približno pri epohi: {start_epoch}")
else:
    print("Jasnega začetka prekomernega prileganja v znotraj treniranih epoh ni.")
# Out:
# Najboljši epoch po val_loss: 4
# Prekomerno prileganje se začne približno pri epohi: 5

# %% [markdown]
# ## Testna natančnost

# %%
test_loss, test_acc = model.evaluate(x_test_vec, y_test, verbose=0)
print(f"Test — loss: {test_loss:.4f}, acc: {test_acc:.4f}")
# Out:
# Test — loss: 0.5957, acc: 0.8501
